# %%
import pandas as pd
import fastf1 as f1

# %%
schedule = f1.get_event_schedule(2023, include_testing=False)
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (24.0 KB) C:\Users\aleca\AppData\Local\Temp\fastf1

# %%
schedule.sort_values(by='EventDate')
# Out:
#     RoundNumber        Country           Location  \
# 1             1        Bahrain             Sakhir
# 2             2   Saudi Arabia             Jeddah
# 3             3      Australia          Melbourne
# 4             4     Azerbaijan               Baku
# 5             5  United States              Miami
# 6             6         Monaco             Monaco
# 7             7          Spain          Barcelona
# 8             8         Canada           Montréal
# 9             9        Austria          Spielberg
# 10           10  Great Britain        Silverstone
# 11           11        Hungary           Budapest
# 12           12        Belgium  Spa-Francorchamps
# 13           13    Netherlands          Zandvoort
# 14           14          Italy              Monza
# 15           15      Singapore         Marina Bay
# 16           16          Japan             Suzuka
# 17           17          Qatar             Lusail
# 18           18  United States             Austin
# ...
